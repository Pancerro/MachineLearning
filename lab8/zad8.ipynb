# %% [markdown]
# <a href="https://colab.research.google.com/github/Pancerro/MachineLearning/blob/master/lab8/zad8" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import requests
data = {
    "student": {
        "name": "Adrian Ławecki",
        "city": "Gdynia"
    }
}
json_string = json.dumps(data)

json_string_indent = json.dumps(data, indent=4)
print(json_string)
print(json_string_indent)

blackjack_hand = (8, "fffs")
encoded_hand = json.dumps(blackjack_hand)
decoded_hand = json.loads(encoded_hand)

blackjack_hand == decoded_hand

type(blackjack_hand)

type(decoded_hand)

blackjack_hand == tuple(decoded_hand)
json_string = """
{
    "kurs": {
        "nazwa": "Python",
        "opis": "Python fajny jest",
        "prowadzacy": [
            {
                "imie": "Python",
                "nazwisko": "Arabski"
            }
        ]
    }
}
"""
data = json.loads(json_string)
print(data)
response = requests.get("https://jsonplaceholder.typicode.com/posts")
posts = json.loads(response.text)
posts == response.json()
type(posts)
posts[:10]
# Map of userId to number of complete TODOs for that user
posts_by_user = {}

# Increment complete TODOs count for each user.
for post in posts:
  try:
    posts_by_user[post["userId"]] += 1
  except KeyError:
    posts_by_user[post["userId"]] = 1
print(posts_by_user)

class Student:
    def __init__(self, wiek, umiejetnosc=None):
        self.wiek = wiek
        self.umiejetnosc = {
            "sila": 2, "zrecznosc": 1, "kondycja": 0,
            "sciaganie": 16, "sennosc": 14, "chec_do_zycia": 13
        } if umiejetnosc is None else umiejetnosc
        self.hp = 10 + self.umiejetnosc["kondycja"]
def encode_complex(z):
    if isinstance(z, complex):
        return (z.real, z.imag)
    else:
        type_name = z.__class__.__name__
        

student = Student(21)
print(json.dumps(student, default=encode_complex))

class ComplexEncoder(json.JSONEncoder):
    def default(self, z):
        if isinstance(z, complex):
            return (z.real, z.imag)
        else:
            return super().default(z)

json.dumps(2 + 52j, cls=ComplexEncoder)
complex_json = json.dumps(42 + 17j, cls=ComplexEncoder)
json.loads(complex_json)
import csv
from google.colab import drive
drive.mount('/content/drive', force_remount=True)


with open('/content/drive/My Drive/excel.txt', mode='w') as employee_file:
    employee_writer = csv.writer(employee_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    employee_writer.writerow(['imie', 'nazwisko'])
    employee_writer.writerow(['c', 'Kadras'])
    employee_writer.writerow(['Eivor', 'Sigurd'])

with open('/content/drive/My Drive/excel.txt', mode='w') as csv_file:
    fieldnames = ['imie', 'nazwisko']
    writer = csv.DictWriter(csv_file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'imie': 'Span', 'nazwisko': 'Spawork'})
    writer.writerow({'imie': 'Eugus', 'nazwisko': 'Mem'})

with open('/content/drive/My Drive/excel.txt', mode='r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Nazwy kolumn {", ".join(row)}')
            line_count += 1
        print(f'\t{row["imie"]} {row["nazwisko"]}')
        line_count += 1
    print(f'Processed {line_count} lines.')

import pandas
df = pandas.read_csv('/content/drive/My Drive/excel.txt')
print(df)
print(type(df['imie'][0]))
df = pandas.read_csv('/content/drive/My Drive/excel.txt', index_col='imie')
print(df)

df = pandas.read_csv('/content/drive/My Drive/excel.txt', index_col='imie', parse_dates=['nazwisko'])
print(df)
print(type(df['nazwisko'][0]))

df = pandas.read_csv('/content/drive/My Drive/excel.txt', 
            index_col='imie', 
            parse_dates=['nazwisko'], 
            header=0, 
            names=['imie', 'nazwisko'])
print(df)
df = pandas.read_csv('/content/drive/My Drive/excel.txt', 
            index_col='imie', 
            parse_dates=['nazwisko'], 
            header=0, 
            names=['imie', 'nazwisko'])
df.to_csv('/content/drive/My Drive/excel.txt')
# Out:
# {"student": {"name": "Adrian \u0141awecki", "city": "Gdynia"}}
# {
#     "student": {
#         "name": "Adrian \u0141awecki",
#         "city": "Gdynia"
#     }
# }
# {'kurs': {'nazwa': 'Python', 'opis': 'Python fajny jest', 'prowadzacy': [{'imie': 'Python', 'nazwisko': 'Arabski'}]}}
# {1: 10, 2: 10, 3: 10, 4: 10, 5: 10, 6: 10, 7: 10, 8: 10, 9: 10, 10: 10}
# null
# Mounted at /content/drive
# Nazwy kolumn imie, nazwisko
# 	Span Spawork
# 	Eugus Mem
# Processed 3 lines.
#     imie nazwisko
# 0   Span  Spawork
# 1  Eugus      Mem
# <class 'str'>
#       nazwisko
# imie
# Span   Spawork
# Eugus      Mem
#       nazwisko
# imie
# Span   Spawork
# Eugus      Mem
# <class 'str'>
#       nazwisko
# imie
# Span   Spawork
# Eugus      Mem
